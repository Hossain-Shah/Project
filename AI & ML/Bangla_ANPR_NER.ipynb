# %%
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in /usr/local/lib/python3.10/dist-packages (1.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from easyocr) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.16.0+cu121)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from easyocr) (4.9.0.80)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.11.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from easyocr) (9.4.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.19.3)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from easyocr) (2.0.2)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (2.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (2024.1.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (23.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->easyocr) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5->easyocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5->easyocr) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5->easyocr) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.5->easyocr) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->easyocr) (1.3.0)

# %%
import easyocr
from PIL import Image
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
import os

# Load spaCy NER model for Bangla language
tokenizer = AutoTokenizer.from_pretrained("sagorsarker/mbert-bengali-ner")
model = AutoModelForTokenClassification.from_pretrained("sagorsarker/mbert-bengali-ner")

nlp = pipeline("ner", model=model, tokenizer=tokenizer, grouped_entities=True)

# Function to perform OCR on an image using EasyOCR
def perform_ocr(image_path):
    reader = easyocr.Reader(['bn'])  # 'bn' is the language code for Bengali
    result = reader.readtext(image_path)
    text = ' '.join([x[1] for x in result])  # Extracting text from the result
    return text

# Function to perform NER on text
def perform_ner(text):
    # Perform NER using transformer-based pipeline
    entities = nlp(text)
    return entities

# Example usage
image_dir = '/content/drive/MyDrive/Colab_Notebooks/Bangla_LPDB/'
training_data = []

for filename in os.listdir(image_dir):
    if filename.endswith('.jpeg'):
        image_path = os.path.join(image_dir, filename)
        text = perform_ocr(image_path)
        named_entities = perform_ner(text)
        print("Image:", filename)
        print("\nOCR Output:")
        print(text)
        print("\nNamed Entities:")
        print(named_entities)
        print("\nEntity word:\tEntity label:")
        for entity in named_entities:
          print(entity['word'], entity['entity_group'])
          print()
        print("--------------------------------------------------")
        entities_list = []
        for entity in named_entities:
            entities_list.append((entity['start'], entity['end'], entity['entity_group']))
        training_data.append((text, {"entities": entities_list}))

# Output the training data in the desired format
output_file = "/content/drive/MyDrive/Colab_Notebooks/Bangla_LPDB_ANPR_semi_annotated.txt"
with open(output_file, "w", encoding="utf-8") as f:
    for text, annotations in training_data:
        f.write(f'("{text}", {annotations}),\n')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# [{'entity_group': 'LABEL_5', 'score': 0.99084777, 'word': 'পদমাখালী', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.99916315, 'word': ': ১২ - ০২৪০', 'start': 9, 'end': 18}]
#
# Entity word:	Entity label:
# পদমাখালী LABEL_5
#
# : ১২ - ০২৪০ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1906.jpeg
#
# OCR Output:
# হ ১৫-১৪৪৫ বগুড়া-
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99165124, 'word': 'হ ১৫ - ১৪৪৫', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_5', 'score': 0.96830744, 'word': 'বগডা', 'start': 10, 'end': 15}, {'entity_group': 'LABEL_0', 'score': 0.9991272, 'word': '-', 'start': 15, 'end': 16}]
#
# Entity word:	Entity label:
# হ ১৫ - ১৪৪৫ LABEL_0
#
# বগডা LABEL_5
#
# - LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1915.jpeg
#
# OCR Output:
# '১৯>৩
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9987036, 'word': "' ১৯ > ৩", 'start': 0, 'end': 5}]
#
# Entity word:	Entity label:
# ' ১৯ > ৩ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1904.jpeg
#
# OCR Output:
# নওগাঁ: হ ১৩-৩০৬৩
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.8081148, 'word': 'নওগা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_0', 'score': 0.9949533, 'word': ': হ ১৩ - ৩০৬৩', 'start': 5, 'end': 16}]
#
# Entity word:	Entity label:
# নওগা LABEL_5
#
# : হ ১৩ - ৩০৬৩ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1911.jpeg
#
# OCR Output:
# 4[47{{7{ ১১-৫৬0
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9993884, 'word': '4 [ 47 { { 7 { ১১ - ৫৬0', 'start': 0, 'end': 15}]
#
# Entity word:	Entity label:
# 4 [ 47 { { 7 { ১১ - ৫৬0 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1908.jpeg
#
# OCR Output:
# য ১-30:0
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.7240279, 'word': 'য', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_0', 'score': 0.9982212, 'word': '১ - 30 : 0', 'start': 2, 'end': 8}]
#
# Entity word:	Entity label:
# য LABEL_3
#
# ১ - 30 : 0 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1914.jpeg
#
# OCR Output:
# জামালপুর- হ @> ৩০২০
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.9930846, 'word': 'জামালপর', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.99943256, 'word': '- হ @ > ৩০২০', 'start': 8, 'end': 19}]
#
# Entity word:	Entity label:
# জামালপর LABEL_5
#
# - হ @ > ৩০২০ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1905.jpeg
#
# OCR Output:
# =য়)$ ূ৬ওযূ^7$ 014] চণথ : 7ঙশঙহ4 ঢাকা মেট্রো-ক ০৩-৮০৬৩
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9995354, 'word': '= য ) $ ৬ওয ^ 7 $ 014 ] চণথ : 7ঙশঙহ4', 'start': 0, 'end': 31}, {'entity_group': 'LABEL_3', 'score': 0.99413174, 'word': 'ঢাকা', 'start': 32, 'end': 36}, {'entity_group': 'LABEL_4', 'score': 0.9401652, 'word': 'মেটরো - ক ০৩', 'start': 37, 'end': 48}, {'entity_group': 'LABEL_0', 'score': 0.7830864, 'word': '-', 'start': 48, 'end': 49}, {'entity_group': 'LABEL_4', 'score': 0.7246158, 'word': '৮০৬৩', 'start': 49, 'end': 53}]
#
# Entity word:	Entity label:
# = য ) $ ৬ওয ^ 7 $ 014 ] চণথ : 7ঙশঙহ4 LABEL_0
#
# ঢাকা LABEL_3
#
# মেটরো - ক ০৩ LABEL_4
#
# - LABEL_0
#
# ৮০৬৩ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1910.jpeg
#
# OCR Output:
# 41201413}1 ১১-৬০৬৯
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99759597, 'word': '41201413 } 1 ১১ - ৬০৬৯', 'start': 0, 'end': 18}]
#
# Entity word:	Entity label:
# 41201413 } 1 ১১ - ৬০৬৯ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1916.jpeg
#
# OCR Output:
# ১১" জামালপুর:
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.999241, 'word': '১১ "', 'start': 0, 'end': 3}, {'entity_group': 'LABEL_5', 'score': 0.87024367, 'word': 'জামালপর', 'start': 4, 'end': 12}, {'entity_group': 'LABEL_0', 'score': 0.9991358, 'word': ':', 'start': 12, 'end': 13}]
#
# Entity word:	Entity label:
# ১১ " LABEL_0
#
# জামালপর LABEL_5
#
# : LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1907.jpeg
#
# OCR Output:
# ঝ?0#&? ঝিনাইদহ ল-১২-১১৯১ মুংঢ
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.997984, 'word': 'ঝ? 0 # &?', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_5', 'score': 0.9819149, 'word': 'ঝিনাইদহ', 'start': 7, 'end': 14}, {'entity_group': 'LABEL_0', 'score': 0.95686257, 'word': 'ল - ১২ - ১১৯১', 'start': 15, 'end': 24}, {'entity_group': 'LABEL_5', 'score': 0.9961707, 'word': 'মংঢ', 'start': 25, 'end': 29}]
#
# Entity word:	Entity label:
# ঝ? 0 # &? LABEL_0
#
# ঝিনাইদহ LABEL_5
#
# ল - ১২ - ১১৯১ LABEL_0
#
# মংঢ LABEL_5
#
# --------------------------------------------------
# Image: Vehicle1912.jpeg
#
# OCR Output:
# সাতক্ষীরা ছ১২৩০০৯
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99828786, 'word': 'সাতকষীরা', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_4', 'score': 0.99710315, 'word': 'ছ১২৩০০৯', 'start': 10, 'end': 17}]
#
# Entity word:	Entity label:
# সাতকষীরা LABEL_3
#
# ছ১২৩০০৯ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1924.jpeg
#
# OCR Output:
# ১১-০৬৬ থ্রীমিন
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.96614087, 'word': '১১ - ০৬৬', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_2', 'score': 0.9885845, 'word': 'থরীমিন', 'start': 7, 'end': 14}]
#
# Entity word:	Entity label:
# ১১ - ০৬৬ LABEL_1
#
# থরীমিন LABEL_2
#
# --------------------------------------------------
# Image: Vehicle1922.jpeg
#
# OCR Output:
# দ মান্স৭? ১১'০৬৬২ জাযমলপুর থ-১১-০৩ ৬১ থয়ুন
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9800497, 'word': 'দ', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_2', 'score': 0.94400686, 'word': 'মানস৭', 'start': 2, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.9989826, 'word': "? ১১ ' ০৬৬২", 'start': 8, 'end': 17}, {'entity_group': 'LABEL_1', 'score': 0.7626641, 'word': 'জ', 'start': 18, 'end': 19}, {'entity_group': 'LABEL_2', 'score': 0.7117854, 'word': '##াযমলপ', 'start': 19, 'end': 24}, {'entity_group': 'LABEL_1', 'score': 0.94060016, 'word': '##র', 'start': 25, 'end': 26}, {'entity_group': 'LABEL_0', 'score': 0.9975794, 'word': 'থ - ১১ - ০৩ ৬১ থযন', 'start': 27, 'end': 42}]
#
# Entity word:	Entity label:
# দ LABEL_1
#
# মানস৭ LABEL_2
#
# ? ১১ ' ০৬৬২ LABEL_0
#
# জ LABEL_1
#
# ##াযমলপ LABEL_2
#
# ##র LABEL_1
#
# থ - ১১ - ০৩ ৬১ থযন LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1919.jpeg
#
# OCR Output:
# সরবরাহ জরুরী ঔষধ {ঞ9? ঢাকা মেট্রো ৫১-৭৭৯২
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9981228, 'word': 'সরবরাহ', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_2', 'score': 0.99838096, 'word': 'জররী ঔষধ', 'start': 7, 'end': 16}, {'entity_group': 'LABEL_0', 'score': 0.9995924, 'word': '{ ঞ9?', 'start': 17, 'end': 21}, {'entity_group': 'LABEL_3', 'score': 0.99818784, 'word': 'ঢাকা', 'start': 22, 'end': 26}, {'entity_group': 'LABEL_4', 'score': 0.986071, 'word': 'মেটরো ৫১', 'start': 27, 'end': 36}, {'entity_group': 'LABEL_0', 'score': 0.88744175, 'word': '- ৭৭৯২', 'start': 36, 'end': 41}]
#
# Entity word:	Entity label:
# সরবরাহ LABEL_1
#
# জররী ঔষধ LABEL_2
#
# { ঞ9? LABEL_0
#
# ঢাকা LABEL_3
#
# মেটরো ৫১ LABEL_4
#
# - ৭৭৯২ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1923.jpeg
#
# OCR Output:
# ^ জামালশুর ১১-১৫২
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99921227, 'word': '^', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_3', 'score': 0.95360124, 'word': 'জামালশর', 'start': 2, 'end': 10}, {'entity_group': 'LABEL_0', 'score': 0.9917251, 'word': '১১ - ১৫২', 'start': 11, 'end': 17}]
#
# Entity word:	Entity label:
# ^ LABEL_0
#
# জামালশর LABEL_3
#
# ১১ - ১৫২ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1917.jpeg
#
# OCR Output:
# জামালপুর- হ ৩০২
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.9629424, 'word': 'জামালপর', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.97909063, 'word': '- হ ৩০২', 'start': 8, 'end': 15}]
#
# Entity word:	Entity label:
# জামালপর LABEL_5
#
# - হ ৩০২ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1925.jpeg
#
# OCR Output:
# পাবনা- হ ১২-৫১৭৪
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.93093306, 'word': 'পাবনা', 'start': 0, 'end': 5}, {'entity_group': 'LABEL_0', 'score': 0.99779, 'word': '- হ ১২ - ৫১৭৪', 'start': 5, 'end': 16}]
#
# Entity word:	Entity label:
# পাবনা LABEL_5
#
# - হ ১২ - ৫১৭৪ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1928.jpeg
#
# OCR Output:
# শরিয়তপুর ১১-৬২৬৪
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.9979224, 'word': 'শরিযতপর', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_6', 'score': 0.9186971, 'word': '১১', 'start': 9, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.9965078, 'word': '- ৬২৬৪', 'start': 11, 'end': 16}]
#
# Entity word:	Entity label:
# শরিযতপর LABEL_5
#
# ১১ LABEL_6
#
# - ৬২৬৪ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1918.jpeg
#
# OCR Output:
# 07! %) $][ 3{) জামালপুর- থ ১১-১৬৭৭ 44341440140 (;_){2 (|৫
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9949879, 'word': '07! % ) $ ] [ 3 { ) জামালপর - থ ১১ - ১৬৭৭ 44341440140 ( ; _ ) { 2 ( | ৫', 'start': 0, 'end': 57}]
#
# Entity word:	Entity label:
# 07! % ) $ ] [ 3 { ) জামালপর - থ ১১ - ১৬৭৭ 44341440140 ( ; _ ) { 2 ( | ৫ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1920.jpeg
#
# OCR Output:
# ১৩-৫০৯৮৮8# [জ বব ংষ!] জামালপ্ খ ১১০৩১৫
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9986595, 'word': '১৩ - ৫০৯৮৮8 # [ জ বব ংষ! ]', 'start': 0, 'end': 21}, {'entity_group': 'LABEL_1', 'score': 0.9935851, 'word': 'জামালপ', 'start': 22, 'end': 28}, {'entity_group': 'LABEL_0', 'score': 0.99835634, 'word': 'খ ১১০৩১৫', 'start': 30, 'end': 38}]
#
# Entity word:	Entity label:
# ১৩ - ৫০৯৮৮8 # [ জ বব ংষ! ] LABEL_0
#
# জামালপ LABEL_1
#
# খ ১১০৩১৫ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1927.jpeg
#
# OCR Output:
# বরাগেরহাট- ১২-৫০০৬
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.9742993, 'word': 'বরাগেরহাট', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.9988914, 'word': '- ১২ - ৫০০৬', 'start': 9, 'end': 18}]
#
# Entity word:	Entity label:
# বরাগেরহাট LABEL_5
#
# - ১২ - ৫০০৬ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1921.jpeg
#
# OCR Output:
# জরুরী ঔষধ সরবরাহ ঢাকা মেট্রো ৫১-৭9৯
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9975503, 'word': 'জররী', 'start': 0, 'end': 5}, {'entity_group': 'LABEL_2', 'score': 0.99377316, 'word': 'ঔষধ সরবরাহ', 'start': 6, 'end': 16}, {'entity_group': 'LABEL_3', 'score': 0.97385514, 'word': 'ঢাকা', 'start': 17, 'end': 21}, {'entity_group': 'LABEL_4', 'score': 0.9909871, 'word': 'মেটরো ৫১', 'start': 22, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.5495077, 'word': '-', 'start': 31, 'end': 32}, {'entity_group': 'LABEL_4', 'score': 0.7436695, 'word': '৭', 'start': 32, 'end': 33}, {'entity_group': 'LABEL_0', 'score': 0.678628, 'word': '##9', 'start': 33, 'end': 34}, {'entity_group': 'LABEL_4', 'score': 0.56532866, 'word': '##৯', 'start': 34, 'end': 35}]
#
# Entity word:	Entity label:
# জররী LABEL_1
#
# ঔষধ সরবরাহ LABEL_2
#
# ঢাকা LABEL_3
#
# মেটরো ৫১ LABEL_4
#
# - LABEL_0
#
# ৭ LABEL_4
#
# ##9 LABEL_0
#
# ##৯ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1926.jpeg
#
# OCR Output:
# &ী&^ জামালপুর- ১১-০০ ৬
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99925786, 'word': '& ী & ^', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_3', 'score': 0.61442995, 'word': 'জামাল', 'start': 5, 'end': 10}, {'entity_group': 'LABEL_0', 'score': 0.93640393, 'word': '##পর - ১১ - ০০ ৬', 'start': 10, 'end': 22}]
#
# Entity word:	Entity label:
# & ী & ^ LABEL_0
#
# জামাল LABEL_3
#
# ##পর - ১১ - ০০ ৬ LABEL_0
#
# --------------------------------------------------
# Image: 93.jpeg
#
# OCR Output:
# থ টাংগাইল ৩৮৯৫ ১১-
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9697916, 'word': 'থ', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_2', 'score': 0.979806, 'word': 'টাংগাইল', 'start': 2, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.9884706, 'word': '৩৮৯৫ ১১ -', 'start': 10, 'end': 18}]
#
# Entity word:	Entity label:
# থ LABEL_1
#
# টাংগাইল LABEL_2
#
# ৩৮৯৫ ১১ - LABEL_0
#
# --------------------------------------------------
# Image: 95.jpeg
#
# OCR Output:
# ৩[ টাংগাইল ১১-১৭৬০
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9977095, 'word': '৩ [', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_3', 'score': 0.9914231, 'word': 'টাংগাইল', 'start': 3, 'end': 10}, {'entity_group': 'LABEL_0', 'score': 0.9292709, 'word': '১১ - ১৭৬০', 'start': 11, 'end': 18}]
#
# Entity word:	Entity label:
# ৩ [ LABEL_0
#
# টাংগাইল LABEL_3
#
# ১১ - ১৭৬০ LABEL_0
#
# --------------------------------------------------
# Image: 96.jpeg
#
# OCR Output:
# টা ? ১২-২২৪২ গাঠল:
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.84076834, 'word': 'টা? ১২ - ২২৪২', 'start': 0, 'end': 12}, {'entity_group': 'LABEL_3', 'score': 0.49913704, 'word': 'গা', 'start': 13, 'end': 15}, {'entity_group': 'LABEL_5', 'score': 0.59998053, 'word': '##ঠল', 'start': 15, 'end': 17}, {'entity_group': 'LABEL_0', 'score': 0.9946502, 'word': ':', 'start': 17, 'end': 18}]
#
# Entity word:	Entity label:
# টা? ১২ - ২২৪২ LABEL_0
#
# গা LABEL_3
#
# ##ঠল LABEL_5
#
# : LABEL_0
#
# --------------------------------------------------
# Image: 97.jpeg
#
# OCR Output:
# ত ঢাংগাহল: ১১-৪১৭৪
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.997127, 'word': 'ত', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_4', 'score': 0.99881077, 'word': 'ঢাংগাহল', 'start': 2, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.99625033, 'word': ': ১১ - ৪১৭৪', 'start': 9, 'end': 18}]
#
# Entity word:	Entity label:
# ত LABEL_3
#
# ঢাংগাহল LABEL_4
#
# : ১১ - ৪১৭৪ LABEL_0
#
# --------------------------------------------------
# Image: 98.jpeg
#
# OCR Output:
# টাংগাইল ১৫-৫৯৮৭
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99884063, 'word': 'টাংগাইল', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_4', 'score': 0.88392717, 'word': '১৫ - ৫৯৮৭', 'start': 8, 'end': 15}]
#
# Entity word:	Entity label:
# টাংগাইল LABEL_3
#
# ১৫ - ৫৯৮৭ LABEL_4
#
# --------------------------------------------------
# Image: 99.jpeg
#
# OCR Output:
# ছ টাংগাইল- ১৫-৫১৮১
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.99873036, 'word': 'ছ', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_2', 'score': 0.9982281, 'word': 'টাংগাইল', 'start': 2, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.996602, 'word': '- ১৫ - ৫১৮১', 'start': 9, 'end': 18}]
#
# Entity word:	Entity label:
# ছ LABEL_1
#
# টাংগাইল LABEL_2
#
# - ১৫ - ৫১৮১ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1521.jpeg
#
# OCR Output:
# বরিশাল মেট্রো- ১১-১৮১১ 9 ( 9 ;
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9959397, 'word': 'বরিশাল', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.9667694, 'word': 'মেটরো - ১১', 'start': 7, 'end': 17}, {'entity_group': 'LABEL_0', 'score': 0.8892659, 'word': '- ১৮১১ 9 ( 9 ;', 'start': 17, 'end': 30}]
#
# Entity word:	Entity label:
# বরিশাল LABEL_3
#
# মেটরো - ১১ LABEL_4
#
# - ১৮১১ 9 ( 9 ; LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1525.jpeg
#
# OCR Output:
# [়হ্ সেহেরব বরিশাল মেট্রেো- থ ১ ১ ১৪৪ ২ হ
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99932456, 'word': '[ হ', 'start': 0, 'end': 3}, {'entity_group': 'LABEL_3', 'score': 0.852415, 'word': 'সেহেরব', 'start': 5, 'end': 11}, {'entity_group': 'LABEL_4', 'score': 0.93886185, 'word': 'বরিশাল মেটরেো -', 'start': 12, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.92824346, 'word': 'থ ১ ১ ১৪৪ ২ হ', 'start': 28, 'end': 41}]
#
# Entity word:	Entity label:
# [ হ LABEL_0
#
# সেহেরব LABEL_3
#
# বরিশাল মেটরেো - LABEL_4
#
# থ ১ ১ ১৪৪ ২ হ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1527.jpeg
#
# OCR Output:
# মেট্রেো বরিশাল ১২-৩৬৪৯
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99730283, 'word': 'মেটরেো', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_4', 'score': 0.9970447, 'word': 'বরিশাল', 'start': 8, 'end': 14}, {'entity_group': 'LABEL_0', 'score': 0.9469935, 'word': '১২ - ৩৬৪৯', 'start': 15, 'end': 22}]
#
# Entity word:	Entity label:
# মেটরেো LABEL_3
#
# বরিশাল LABEL_4
#
# ১২ - ৩৬৪৯ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1529.jpeg
#
# OCR Output:
# ত_০৫য 0 1 বরিশাল মেট্রো- ল ১১-৮৪৭৮
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.998882, 'word': 'ত _ ০৫য 0 1', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_3', 'score': 0.99917066, 'word': 'বরিশাল', 'start': 10, 'end': 16}, {'entity_group': 'LABEL_4', 'score': 0.98941296, 'word': 'মেটরো - ল ১১', 'start': 17, 'end': 29}, {'entity_group': 'LABEL_0', 'score': 0.87813014, 'word': '- ৮৪৭৮', 'start': 29, 'end': 34}]
#
# Entity word:	Entity label:
# ত _ ০৫য 0 1 LABEL_0
#
# বরিশাল LABEL_3
#
# মেটরো - ল ১১ LABEL_4
#
# - ৮৪৭৮ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1524.jpeg
#
# OCR Output:
# বরিশাস মেট্রো ১২-১৩৩১
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99374616, 'word': 'বরিশাস', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.97779584, 'word': 'মেটরো', 'start': 7, 'end': 13}, {'entity_group': 'LABEL_0', 'score': 0.94579804, 'word': '১২ - ১৩৩১', 'start': 14, 'end': 21}]
#
# Entity word:	Entity label:
# বরিশাস LABEL_3
#
# মেটরো LABEL_4
#
# ১২ - ১৩৩১ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1530.jpeg
#
# OCR Output:
# 9 নস ধচ দাংন যরেশাল মেট্রো- হ ১২-৯৩২৫ কেকেদর ঝাহুঁ  (স্মেঔুমদফক
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.87165815, 'word': '9 নস', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_3', 'score': 0.6546564, 'word': 'ধচ', 'start': 5, 'end': 7}, {'entity_group': 'LABEL_4', 'score': 0.8655449, 'word': 'দাংন যরেশাল মেটরো - হ', 'start': 8, 'end': 29}, {'entity_group': 'LABEL_0', 'score': 0.87123466, 'word': '১২ - ৯৩২৫ কেকে', 'start': 30, 'end': 42}, {'entity_group': 'LABEL_1', 'score': 0.774508, 'word': '##দর', 'start': 42, 'end': 44}, {'entity_group': 'LABEL_4', 'score': 0.50167185, 'word': 'ঝ', 'start': 45, 'end': 46}, {'entity_group': 'LABEL_2', 'score': 0.5066712, 'word': '##াহ', 'start': 46, 'end': 48}, {'entity_group': 'LABEL_0', 'score': 0.90621984, 'word': '( সমেঔমদফক', 'start': 52, 'end': 63}]
#
# Entity word:	Entity label:
# 9 নস LABEL_0
#
# ধচ LABEL_3
#
# দাংন যরেশাল মেটরো - হ LABEL_4
#
# ১২ - ৯৩২৫ কেকে LABEL_0
#
# ##দর LABEL_1
#
# ঝ LABEL_4
#
# ##াহ LABEL_2
#
# ( সমেঔমদফক LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1526.jpeg
#
# OCR Output:
# মৌবী:01715-15 3320 মেট্রো ১৯০৯ হ{ বরিশাল মেট্রো ১১-১৯০৯ ' [0
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.96413934, 'word': 'মৌবী : 01715 - 15 3320', 'start': 0, 'end': 18}, {'entity_group': 'LABEL_3', 'score': 0.9856156, 'word': 'মেটরো', 'start': 19, 'end': 25}, {'entity_group': 'LABEL_4', 'score': 0.63469356, 'word': '১৯', 'start': 26, 'end': 28}, {'entity_group': 'LABEL_0', 'score': 0.8799411, 'word': '##০৯ হ {', 'start': 28, 'end': 33}, {'entity_group': 'LABEL_3', 'score': 0.99272877, 'word': 'বরিশাল', 'start': 34, 'end': 40}, {'entity_group': 'LABEL_4', 'score': 0.98170745, 'word': 'মেটরো', 'start': 41, 'end': 47}, {'entity_group': 'LABEL_0', 'score': 0.99132836, 'word': "১১ - ১৯০৯ ' [ 0", 'start': 48, 'end': 60}]
#
# Entity word:	Entity label:
# মৌবী : 01715 - 15 3320 LABEL_0
#
# মেটরো LABEL_3
#
# ১৯ LABEL_4
#
# ##০৯ হ { LABEL_0
#
# বরিশাল LABEL_3
#
# মেটরো LABEL_4
#
# ১১ - ১৯০৯ ' [ 0 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1528.jpeg
#
# OCR Output:
# বরিশাল মেট্রো- ১২-১১৮৬
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9974678, 'word': 'বরিশাল', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.874001, 'word': 'মেটরো - ১২', 'start': 7, 'end': 17}, {'entity_group': 'LABEL_0', 'score': 0.7763721, 'word': '- ১১', 'start': 17, 'end': 20}, {'entity_group': 'LABEL_4', 'score': 0.54810256, 'word': '##৮৬', 'start': 20, 'end': 22}]
#
# Entity word:	Entity label:
# বরিশাল LABEL_3
#
# মেটরো - ১২ LABEL_4
#
# - ১১ LABEL_0
#
# ##৮৬ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1523.jpeg
#
# OCR Output:
# বরিশান হ১২-৩৬৪৮ {_; @েটো
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9951782, 'word': 'বরিশান', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_2', 'score': 0.92426324, 'word': 'হ১২', 'start': 7, 'end': 10}, {'entity_group': 'LABEL_0', 'score': 0.9996008, 'word': '- ৩৬৪৮ { _ ; @ েটো', 'start': 10, 'end': 24}]
#
# Entity word:	Entity label:
# বরিশান LABEL_1
#
# হ১২ LABEL_2
#
# - ৩৬৪৮ { _ ; @ েটো LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1532.jpeg
#
# OCR Output:
# _{0]0 [ ঢাকা মেচেদ্র] ১১-৭৩৩
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9995744, 'word': '_ { 0 ] 0 [', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_3', 'score': 0.97963357, 'word': 'ঢাকা', 'start': 8, 'end': 12}, {'entity_group': 'LABEL_4', 'score': 0.9571786, 'word': 'মেচেদর', 'start': 13, 'end': 20}, {'entity_group': 'LABEL_0', 'score': 0.9991412, 'word': '] ১১ - ৭৩৩', 'start': 20, 'end': 28}]
#
# Entity word:	Entity label:
# _ { 0 ] 0 [ LABEL_0
#
# ঢাকা LABEL_3
#
# মেচেদর LABEL_4
#
# ] ১১ - ৭৩৩ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1522.jpeg
#
# OCR Output:
# 9 ১২ মেট্রো বরিশাল ৯৭৪৩
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.61335945, 'word': '9 ১২', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.9986035, 'word': 'মেটরো বরিশাল ৯৭৪৩', 'start': 5, 'end': 23}]
#
# Entity word:	Entity label:
# 9 ১২ LABEL_3
#
# মেটরো বরিশাল ৯৭৪৩ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1534.jpeg
#
# OCR Output:
# মেট্রো ঢাকা | )৩-৫৮09 9=74
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9882517, 'word': 'মেটরো', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.769626, 'word': 'ঢাকা', 'start': 7, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.99933857, 'word': '| ) ৩ - ৫৮09 9 = 74', 'start': 12, 'end': 26}]
#
# Entity word:	Entity label:
# মেটরো LABEL_3
#
# ঢাকা LABEL_4
#
# | ) ৩ - ৫৮09 9 = 74 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1547.jpeg
#
# OCR Output:
# 9৫0৮= ঢা41 মেট্রেো ৩৫-৬৫৮৭
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9986936, 'word': '9৫0৮ =', 'start': 0, 'end': 5}, {'entity_group': 'LABEL_3', 'score': 0.93934685, 'word': 'ঢা41', 'start': 6, 'end': 10}, {'entity_group': 'LABEL_4', 'score': 0.87347925, 'word': 'মেটরেো', 'start': 11, 'end': 18}, {'entity_group': 'LABEL_0', 'score': 0.9977406, 'word': '৩৫ - ৬৫৮৭', 'start': 19, 'end': 26}]
#
# Entity word:	Entity label:
# 9৫0৮ = LABEL_0
#
# ঢা41 LABEL_3
#
# মেটরেো LABEL_4
#
# ৩৫ - ৬৫৮৭ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1537.jpeg
#
# OCR Output:
# ;1;81|6=0 -৮0][-
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9996267, 'word': '; 1 ; 81 | 6 = 0 - ৮0 ] [ -', 'start': 0, 'end': 16}]
#
# Entity word:	Entity label:
# ; 1 ; 81 | 6 = 0 - ৮0 ] [ - LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1539.jpeg
#
# OCR Output:
# াশঞ0ো ৮হ7চ71 +9348|
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9035803, 'word': 'াশঞ0ো ৮হ7চ71 + 9348 |', 'start': 0, 'end': 19}]
#
# Entity word:	Entity label:
# াশঞ0ো ৮হ7চ71 + 9348 | LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1557.jpeg
#
# OCR Output:
# 001^ 17]3 তবচযচ3 ১১-০১১৭
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.8728989, 'word': '001 ^ 17 ] 3 তবচযচ3 ১১ - ০১১৭', 'start': 0, 'end': 24}]
#
# Entity word:	Entity label:
# 001 ^ 17 ] 3 তবচযচ3 ১১ - ০১১৭ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1560.jpeg
#
# OCR Output:
# [0=>: ১৬84 _চছ
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.96739924, 'word': '[ 0 = > : ১৬84 _ চছ', 'start': 0, 'end': 14}]
#
# Entity word:	Entity label:
# [ 0 = > : ১৬84 _ চছ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1564.jpeg
#
# OCR Output:
# িলেড ১১0৩২9|
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.975127, 'word': 'িলেড', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_0', 'score': 0.989265, 'word': '১১0৩২9 |', 'start': 5, 'end': 12}]
#
# Entity word:	Entity label:
# িলেড LABEL_3
#
# ১১0৩২9 | LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1570.jpeg
#
# OCR Output:
# ঢাকী শেন্ডয ৩৫-৫৩৭০
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.98996425, 'word': 'ঢাকী', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_6', 'score': 0.99560285, 'word': 'শেনডয', 'start': 5, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.9995536, 'word': '৩৫ - ৫৩৭০', 'start': 12, 'end': 19}]
#
# Entity word:	Entity label:
# ঢাকী LABEL_5
#
# শেনডয LABEL_6
#
# ৩৫ - ৫৩৭০ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1567.jpeg
#
# OCR Output:
# '9[ ^ `][ েন|দ1 ঢাকা মেদ্রো-ক ১২ং০০88 সরদাধ
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99968076, 'word': "' 9 [ ^ ` ] [ েন | দ1", 'start': 0, 'end': 15}, {'entity_group': 'LABEL_3', 'score': 0.9841616, 'word': 'ঢাকা', 'start': 16, 'end': 20}, {'entity_group': 'LABEL_4', 'score': 0.9937233, 'word': 'মেদরো - ক', 'start': 21, 'end': 29}, {'entity_group': 'LABEL_0', 'score': 0.9989931, 'word': '১২ং০০88', 'start': 30, 'end': 37}, {'entity_group': 'LABEL_5', 'score': 0.9239104, 'word': 'সরদাধ', 'start': 38, 'end': 43}]
#
# Entity word:	Entity label:
# ' 9 [ ^ ` ] [ েন | দ1 LABEL_0
#
# ঢাকা LABEL_3
#
# মেদরো - ক LABEL_4
#
# ১২ং০০88 LABEL_0
#
# সরদাধ LABEL_5
#
# --------------------------------------------------
# Image: Vehicle1563.jpeg
#
# OCR Output:
# ৩১ বিলেট : ১৯-০'
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.47157392, 'word': '৩১', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_2', 'score': 0.93038255, 'word': 'বিলেট', 'start': 3, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.9995748, 'word': ": ১৯ - ০ '", 'start': 9, 'end': 16}]
#
# Entity word:	Entity label:
# ৩১ LABEL_1
#
# বিলেট LABEL_2
#
# : ১৯ - ০ ' LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1585.jpeg
#
# OCR Output:
# ঢাকা মেট্রো-খ ১৩-১২৬৫ ৬!গ: ঢঢ|৮ধ 32৬20:0১ 13-1265
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99761283, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.98086834, 'word': 'মেটরো', 'start': 5, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.99897385, 'word': '- খ ১৩ - ১২৬৫ ৬! গ : ঢঢ | ৮ধ 32৬20 : 0১ 13 - 1265', 'start': 11, 'end': 49}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরো LABEL_4
#
# - খ ১৩ - ১২৬৫ ৬! গ : ঢঢ | ৮ধ 32৬20 : 0১ 13 - 1265 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1575.jpeg
#
# OCR Output:
# মেট্রো ঢাকা | )৩-৫৮09 9=74
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9882517, 'word': 'মেটরো', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.769626, 'word': 'ঢাকা', 'start': 7, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.99933857, 'word': '| ) ৩ - ৫৮09 9 = 74', 'start': 12, 'end': 26}]
#
# Entity word:	Entity label:
# মেটরো LABEL_3
#
# ঢাকা LABEL_4
#
# | ) ৩ - ৫৮09 9 = 74 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1586.jpeg
#
# OCR Output:
# ঢাকা মেট্রো- গ ১৫-০৫৬৮ (]1:  `হহ৮ চূড&`-৬` 15-0568
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99834156, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.9755883, 'word': 'মেটরো - গ ১৫', 'start': 5, 'end': 17}, {'entity_group': 'LABEL_0', 'score': 0.9687101, 'word': '- ০৫৬৮ ( ] 1 : ` হহ৮ চড & ` - ৬ ` 15 - 0568', 'start': 17, 'end': 50}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরো - গ ১৫ LABEL_4
#
# - ০৫৬৮ ( ] 1 : ` হহ৮ চড & ` - ৬ ` 15 - 0568 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1598.jpeg
#
# OCR Output:
# ঢাকা মেট্রো-গ ১৭-৬৮৮৪ {এহ৫হব গহ |হরগ= ঢঃ=:
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9980975, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.98955154, 'word': 'মেটরো - গ', 'start': 5, 'end': 13}, {'entity_group': 'LABEL_0', 'score': 0.99843234, 'word': '১৭ - ৬৮৮৪ { এহ৫হব গহ | হরগ = ঢঃ = :', 'start': 14, 'end': 42}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরো - গ LABEL_4
#
# ১৭ - ৬৮৮৪ { এহ৫হব গহ | হরগ = ঢঃ = : LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1607.jpeg
#
# OCR Output:
# চট্ট মেট্রো গ ১১-৭২৮৮
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9988835, 'word': 'চটট', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.9827204, 'word': 'মেটরো গ ১১ - ৭২৮৮', 'start': 5, 'end': 21}]
#
# Entity word:	Entity label:
# চটট LABEL_3
#
# মেটরো গ ১১ - ৭২৮৮ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1610.jpeg
#
# OCR Output:
# ঢাকা মেট্রো: ০৩:৩9( ও১ম 50৫ধ [যত০
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9956741, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.969402, 'word': 'মেটরো', 'start': 5, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.9993637, 'word': ': ০৩ : ৩9 ( ও১ম 50৫ধ [ যত০', 'start': 11, 'end': 33}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরো LABEL_4
#
# : ০৩ : ৩9 ( ও১ম 50৫ধ [ যত০ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1606.jpeg
#
# OCR Output:
# ঢকােট্র] ৮১৪১88
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.7119523, 'word': 'ঢকােটর', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.9952093, 'word': '] ৮১৪১88', 'start': 7, 'end': 15}]
#
# Entity word:	Entity label:
# ঢকােটর LABEL_3
#
# ] ৮১৪১88 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1605.jpeg
#
# OCR Output:
# দব 1াও 0১৫২১
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9318548, 'word': 'দব', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_4', 'score': 0.5956928, 'word': '1', 'start': 3, 'end': 4}, {'entity_group': 'LABEL_3', 'score': 0.46095487, 'word': '##াও', 'start': 4, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.82978946, 'word': '0১৫২১', 'start': 7, 'end': 12}]
#
# Entity word:	Entity label:
# দব LABEL_3
#
# 1 LABEL_4
#
# ##াও LABEL_3
#
# 0১৫২১ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1608.jpeg
#
# OCR Output:
# ঢাকা মেট্রো-গ ৯৪২৫ [11,[['111: []33#356 1!="11-54-35-9425
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99768305, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.99589795, 'word': 'মেটরো - গ ৯৪২৫', 'start': 5, 'end': 18}, {'entity_group': 'LABEL_0', 'score': 0.9996616, 'word': '[ 11, [ [ \' 111 : [ ] 33 # 356 1! = " 11 - 54 - 35 - 9425', 'start': 19, 'end': 57}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরো - গ ৯৪২৫ LABEL_4
#
# [ 11, [ [ ' 111 : [ ] 33 # 356 1! = " 11 - 54 - 35 - 9425 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1609.jpeg
#
# OCR Output:
# ঢাকা মেট্রো-গ ১৫-৬৭0৭
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99919945, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.99572414, 'word': 'মেটরো - গ ১৫ - ৬৭0৭', 'start': 5, 'end': 21}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরো - গ ১৫ - ৬৭0৭ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1611.jpeg
#
# OCR Output:
# ঢাকা মেট্রো- হ ৫৫-৪8১১
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9993255, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.9983888, 'word': 'মেটরো - হ ৫৫ - ৪8১১', 'start': 5, 'end': 22}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরো - হ ৫৫ - ৪8১১ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1721.jpeg
#
# OCR Output:
# ঢাকা মেট্রো- খ ১১-৮০০৫ [[.[!11111; ঢঘ3৮ ![3676:0!3 11&0ূ5
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.998103, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.9031087, 'word': 'মেটরো - খ ১১', 'start': 5, 'end': 17}, {'entity_group': 'LABEL_0', 'score': 0.86668074, 'word': '-', 'start': 17, 'end': 18}, {'entity_group': 'LABEL_4', 'score': 0.6868833, 'word': '৮০০৫', 'start': 18, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.9996406, 'word': '[ [. [! 11111 ; ঢঘ3৮! [ 3676 : 0! 3 11 & 05', 'start': 23, 'end': 57}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরো - খ ১১ LABEL_4
#
# - LABEL_0
#
# ৮০০৫ LABEL_4
#
# [ [. [! 11111 ; ঢঘ3৮! [ 3676 : 0! 3 11 & 05 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1745.jpeg
#
# OCR Output:
# ১১ ময়মনসিংহ ৯৪৪০
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.73307705, 'word': '১১ মযমনসিং', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_4', 'score': 0.84658515, 'word': '##হ ৯৪৪০', 'start': 11, 'end': 17}]
#
# Entity word:	Entity label:
# ১১ মযমনসিং LABEL_3
#
# ##হ ৯৪৪০ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1746.jpeg
#
# OCR Output:
# [704<265[340 ময়মনসিংহ- ল ১১-উঠব
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99961734, 'word': '[ 704 < 265 [ 340', 'start': 0, 'end': 12}, {'entity_group': 'LABEL_1', 'score': 0.9803555, 'word': 'মযমনসিংহ - ল', 'start': 13, 'end': 25}, {'entity_group': 'LABEL_0', 'score': 0.9267565, 'word': '১১ - উঠব', 'start': 26, 'end': 32}]
#
# Entity word:	Entity label:
# [ 704 < 265 [ 340 LABEL_0
#
# মযমনসিংহ - ল LABEL_1
#
# ১১ - উঠব LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1743.jpeg
#
# OCR Output:
# পঞ্চগড়: ল ১১-০৪২২
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99834144, 'word': 'পঞচগড', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.95316494, 'word': ': ল ১১ - ০৪২২', 'start': 6, 'end': 17}]
#
# Entity word:	Entity label:
# পঞচগড LABEL_3
#
# : ল ১১ - ০৪২২ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1749.jpeg
#
# OCR Output:
# হ ময়মনসিংহ- ১৫-২৬৬৪
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9991781, 'word': 'হ', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_2', 'score': 0.9991393, 'word': 'মযমনসিংহ', 'start': 2, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.99915487, 'word': '- ১৫ - ২৬৬৪', 'start': 11, 'end': 20}]
#
# Entity word:	Entity label:
# হ LABEL_1
#
# মযমনসিংহ LABEL_2
#
# - ১৫ - ২৬৬৪ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1747.jpeg
#
# OCR Output:
# ময়মনসিংহ- হ ১৫-৩৬৯৮
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9737769, 'word': 'মযমনসিংহ', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.995428, 'word': '- হ ১৫ - ৩৬৯৮', 'start': 9, 'end': 20}]
#
# Entity word:	Entity label:
# মযমনসিংহ LABEL_3
#
# - হ ১৫ - ৩৬৯৮ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1742.jpeg
#
# OCR Output:
# ঢাকা মেট্রে 5| ২২-৭৭২৫
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9973695, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.98126817, 'word': 'মেটরে 5', 'start': 5, 'end': 13}, {'entity_group': 'LABEL_0', 'score': 0.98249775, 'word': '| ২২ - ৭৭২৫', 'start': 13, 'end': 22}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরে 5 LABEL_4
#
# | ২২ - ৭৭২৫ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1744.jpeg
#
# OCR Output:
# সিংহ: ১৫-৪৪৮১
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.97716314, 'word': 'সিংহ', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_0', 'score': 0.9931815, 'word': ': ১৫ - ৪৪৮১', 'start': 4, 'end': 13}]
#
# Entity word:	Entity label:
# সিংহ LABEL_5
#
# : ১৫ - ৪৪৮১ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1741.jpeg
#
# OCR Output:
# 4"[[[ ঠাকুরগাও: 5ে ১২-৯৪৯৭
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9842879, 'word': '4 " [ [ [ ঠাকরগাও : 5ে ১২ - ৯৪৯৭', 'start': 0, 'end': 26}]
#
# Entity word:	Entity label:
# 4 " [ [ [ ঠাকরগাও : 5ে ১২ - ৯৪৯৭ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1748.jpeg
#
# OCR Output:
# ১৪ ৯৪৬৮ ময়মনসিংহ:- ১১-৯১৪৫
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9883293, 'word': '১৪ ৯৪৬৮', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_3', 'score': 0.5854406, 'word': 'মযমনসিংহ', 'start': 8, 'end': 17}, {'entity_group': 'LABEL_0', 'score': 0.9991983, 'word': ': - ১১ - ৯১৪৫', 'start': 17, 'end': 27}]
#
# Entity word:	Entity label:
# ১৪ ৯৪৬৮ LABEL_0
#
# মযমনসিংহ LABEL_3
#
# : - ১১ - ৯১৪৫ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1760.jpeg
#
# OCR Output:
# ময়মনসিংহ- ল ১১-৬৭৪৯
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.95469385, 'word': 'মযমনসিংহ', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.9023016, 'word': '-', 'start': 9, 'end': 10}, {'entity_group': 'LABEL_3', 'score': 0.7008415, 'word': 'ল', 'start': 11, 'end': 12}, {'entity_group': 'LABEL_0', 'score': 0.9949036, 'word': '১১ - ৬৭৪৯', 'start': 13, 'end': 20}]
#
# Entity word:	Entity label:
# মযমনসিংহ LABEL_3
#
# - LABEL_0
#
# ল LABEL_3
#
# ১১ - ৬৭৪৯ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1750.jpeg
#
# OCR Output:
# [মনসিংহ- ১৪-৯৪৬৮
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99748254, 'word': '[ মনসিংহ - ১৪ - ৯৪৬৮', 'start': 0, 'end': 16}]
#
# Entity word:	Entity label:
# [ মনসিংহ - ১৪ - ৯৪৬৮ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1756.jpeg
#
# OCR Output:
# মমনপিতে: 8030 ময়মনসিংহ- ১৫-৩৩৮৬ ভ্র
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.9321898, 'word': 'মমনপিতে', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.7884757, 'word': ': 8030 মযমনসি', 'start': 7, 'end': 21}, {'entity_group': 'LABEL_3', 'score': 0.56657237, 'word': '##ংহ', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.85296446, 'word': '- ১৫ - ৩৩৮৬', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_4', 'score': 0.8869128, 'word': 'ভর', 'start': 33, 'end': 36}]
#
# Entity word:	Entity label:
# মমনপিতে LABEL_5
#
# : 8030 মযমনসি LABEL_0
#
# ##ংহ LABEL_3
#
# - ১৫ - ৩৩৮৬ LABEL_0
#
# ভর LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1762.jpeg
#
# OCR Output:
# ময়মনসিংহ- ১৫-৪৫৫৫ |<
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.90808374, 'word': 'মযমনসিংহ', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.99941134, 'word': '- ১৫ - ৪৫৫৫ | <', 'start': 9, 'end': 21}]
#
# Entity word:	Entity label:
# মযমনসিংহ LABEL_5
#
# - ১৫ - ৪৫৫৫ | < LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1761.jpeg
#
# OCR Output:
# ময়মনসিংহ- ১১-৭৪৮১ মাস্টার
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.74288636, 'word': 'মযমনসিংহ', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.91182345, 'word': '- ১১ - ৭৪৮১ মাসটার', 'start': 9, 'end': 26}]
#
# Entity word:	Entity label:
# মযমনসিংহ LABEL_5
#
# - ১১ - ৭৪৮১ মাসটার LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1759.jpeg
#
# OCR Output:
# ত ময়মনসিংহ- ১৫ -৩৩
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9983935, 'word': 'ত', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_2', 'score': 0.99890476, 'word': 'মযমনসিংহ', 'start': 2, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.99943036, 'word': '- ১৫ - ৩৩', 'start': 11, 'end': 19}]
#
# Entity word:	Entity label:
# ত LABEL_1
#
# মযমনসিংহ LABEL_2
#
# - ১৫ - ৩৩ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1757.jpeg
#
# OCR Output:
# ১১-৬০ ৪০ ১৯ ময়মনসিংহ: ল ১১-৮৮১২
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99834204, 'word': '১১ - ৬০ ৪০ ১৯', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_5', 'score': 0.92195106, 'word': 'মযমনসিংহ', 'start': 12, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.99778634, 'word': ': ল ১১ - ৮৮১২', 'start': 21, 'end': 32}]
#
# Entity word:	Entity label:
# ১১ - ৬০ ৪০ ১৯ LABEL_0
#
# মযমনসিংহ LABEL_5
#
# : ল ১১ - ৮৮১২ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1754.jpeg
#
# OCR Output:
# ময়মনসিংহ: ছ ১৪-৬৬৩০ 54)181
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.9805456, 'word': 'মযমনসিংহ', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.99919206, 'word': ': ছ ১৪ - ৬৬৩০ 54 ) 181', 'start': 9, 'end': 27}]
#
# Entity word:	Entity label:
# মযমনসিংহ LABEL_5
#
# : ছ ১৪ - ৬৬৩০ 54 ) 181 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1751.jpeg
#
# OCR Output:
# ৪৫২৫' ময়মনসিংহ- ৩-৬৯২৪
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.936094, 'word': "৪৫২৫ ' মযমনসিংহ - ৩ - ৬৯২৪", 'start': 0, 'end': 23}]
#
# Entity word:	Entity label:
# ৪৫২৫ ' মযমনসিংহ - ৩ - ৬৯২৪ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1753.jpeg
#
# OCR Output:
# 4১৭৫ ১৪ 489[4+4|]? ময়4র-  ম:চ :৭908
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99738777, 'word': '4১৭৫ ১৪ 489 [ 4 + 4 | ]? ময4র - ম : চ : ৭908', 'start': 0, 'end': 35}]
#
# Entity word:	Entity label:
# 4১৭৫ ১৪ 489 [ 4 + 4 | ]? ময4র - ম : চ : ৭908 LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1752.jpeg
#
# OCR Output:
# ময়মনসিংত: ল ১১-৪৫২৫
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.9885023, 'word': 'মযমনসিংত', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.9952518, 'word': ': ল ১১ - ৪৫২৫', 'start': 9, 'end': 20}]
#
# Entity word:	Entity label:
# মযমনসিংত LABEL_5
#
# : ল ১১ - ৪৫২৫ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1758.jpeg
#
# OCR Output:
# [৫: ময়মনসিংহ হ ১৩-৫৬৭১
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.999418, 'word': '[ ৫ :', 'start': 0, 'end': 3}, {'entity_group': 'LABEL_5', 'score': 0.7886918, 'word': 'মযমনসিংহ', 'start': 4, 'end': 13}, {'entity_group': 'LABEL_0', 'score': 0.96094525, 'word': 'হ ১৩ - ৫৬৭১', 'start': 14, 'end': 23}]
#
# Entity word:	Entity label:
# [ ৫ : LABEL_0
#
# মযমনসিংহ LABEL_5
#
# হ ১৩ - ৫৬৭১ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1755.jpeg
#
# OCR Output:
# ঢ!কা মো;া- ল ৩৫-৫ ০৮৭
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.68454295, 'word': 'ঢ!', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_1', 'score': 0.9659442, 'word': 'কা', 'start': 2, 'end': 4}, {'entity_group': 'LABEL_2', 'score': 0.99318445, 'word': 'মো', 'start': 5, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.9840426, 'word': '; া - ল ৩৫ - ৫ ০৮৭', 'start': 8, 'end': 22}]
#
# Entity word:	Entity label:
# ঢ! LABEL_0
#
# কা LABEL_1
#
# মো LABEL_2
#
# ; া - ল ৩৫ - ৫ ০৮৭ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1765.jpeg
#
# OCR Output:
# পর@ে খাগড়াছড়ি: ১১-৬৯৪৩
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.93617636, 'word': 'পর @ ে', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.99615955, 'word': 'খাগডাছডি', 'start': 5, 'end': 13}, {'entity_group': 'LABEL_0', 'score': 0.9977226, 'word': ': ১১ - ৬৯৪৩', 'start': 13, 'end': 22}]
#
# Entity word:	Entity label:
# পর @ ে LABEL_3
#
# খাগডাছডি LABEL_4
#
# : ১১ - ৬৯৪৩ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1769.jpeg
#
# OCR Output:
# 91]34[7[3114 4|ও|ু৯ 7হ০&হ$ খাগড়াছড়ি: ১১-৬৫৯০
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9988138, 'word': '91 ] 34 [ 7 [ 3114 4 | ও | ৯ 7হ০ & হ $', 'start': 0, 'end': 26}, {'entity_group': 'LABEL_3', 'score': 0.8105566, 'word': 'খাগডাছডি', 'start': 27, 'end': 35}, {'entity_group': 'LABEL_0', 'score': 0.99947345, 'word': ': ১১ - ৬৫৯০', 'start': 35, 'end': 44}]
#
# Entity word:	Entity label:
# 91 ] 34 [ 7 [ 3114 4 | ও | ৯ 7হ০ & হ $ LABEL_0
#
# খাগডাছডি LABEL_3
#
# : ১১ - ৬৫৯০ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1772.jpeg
#
# OCR Output:
# ~ম4465 ঢাকামলেট্রো হ8৬৮৮২৮
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99679565, 'word': '~ ম4465', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_3', 'score': 0.9096207, 'word': 'ঢাকামলেটরো', 'start': 7, 'end': 18}, {'entity_group': 'LABEL_4', 'score': 0.99746895, 'word': 'হ8৬৮৮২৮', 'start': 19, 'end': 26}]
#
# Entity word:	Entity label:
# ~ ম4465 LABEL_0
#
# ঢাকামলেটরো LABEL_3
#
# হ8৬৮৮২৮ LABEL_4
#
# --------------------------------------------------
# Image: Vehicle1763.jpeg
#
# OCR Output:
# ময়মনসিংহ- হ ১৪-৪২২৪
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.5693526, 'word': 'ময', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_3', 'score': 0.48514384, 'word': '##মনসি', 'start': 3, 'end': 7}, {'entity_group': 'LABEL_5', 'score': 0.5658008, 'word': '##ংহ', 'start': 7, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.99897766, 'word': '- হ ১৪ - ৪২২৪', 'start': 9, 'end': 20}]
#
# Entity word:	Entity label:
# ময LABEL_5
#
# ##মনসি LABEL_3
#
# ##ংহ LABEL_5
#
# - হ ১৪ - ৪২২৪ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1774.jpeg
#
# OCR Output:
# 692;) খাগড়াছড়ি ১১-০৬২৪
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9992406, 'word': '692 ; )', 'start': 0, 'end': 5}, {'entity_group': 'LABEL_3', 'score': 0.9986458, 'word': 'খাগডাছডি', 'start': 6, 'end': 14}, {'entity_group': 'LABEL_4', 'score': 0.6179605, 'word': '১১', 'start': 15, 'end': 17}, {'entity_group': 'LABEL_0', 'score': 0.92628956, 'word': '- ০৬২৪', 'start': 17, 'end': 22}]
#
# Entity word:	Entity label:
# 692 ; ) LABEL_0
#
# খাগডাছডি LABEL_3
#
# ১১ LABEL_4
#
# - ০৬২৪ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1775.jpeg
#
# OCR Output:
# ৫^চ9~16 5?^হ৫6 38[1244[0 001_[06-54[[ 443779 14,990 5?^হং5থ 57ঞহং 6ঋম 9,990 0071{42{ষ"6 10.990 ৬"প99? দ9ঝ!6(9  12 490| খাগড়াছড়ি ১১-৪৫৮৪
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99951357, 'word': '৫ ^ চ9 ~ 16 5? ^ হ৫6 38 [ 1244 [ 0 001 _ [ 06 - 54 [ [ 443779 14, 990 5? ^ হং5থ 57ঞহং 6ঋম 9, 990 0071 { 42 { ষ " 6 10. 990 ৬ " প99? দ9ঝ! 6 ( 9 12 490 |', 'start': 0, 'end': 118}, {'entity_group': 'LABEL_3', 'score': 0.9222084, 'word': 'খাগডাছডি', 'start': 119, 'end': 127}, {'entity_group': 'LABEL_0', 'score': 0.9968595, 'word': '১১ - ৪৫৮৪', 'start': 128, 'end': 135}]
#
# Entity word:	Entity label:
# ৫ ^ চ9 ~ 16 5? ^ হ৫6 38 [ 1244 [ 0 001 _ [ 06 - 54 [ [ 443779 14, 990 5? ^ হং5থ 57ঞহং 6ঋম 9, 990 0071 { 42 { ষ " 6 10. 990 ৬ " প99? দ9ঝ! 6 ( 9 12 490 | LABEL_0
#
# খাগডাছডি LABEL_3
#
# ১১ - ৪৫৮৪ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1768.jpeg
#
# OCR Output:
# 0: ৬=/্$# খাগড়াছড়ি ০২৩১ ০২
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9993768, 'word': '0 : ৬ = / $ #', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_3', 'score': 0.99435234, 'word': 'খাগডাছডি', 'start': 10, 'end': 18}, {'entity_group': 'LABEL_0', 'score': 0.92476773, 'word': '০২৩১ ০২', 'start': 19, 'end': 26}]
#
# Entity word:	Entity label:
# 0 : ৬ = / $ # LABEL_0
#
# খাগডাছডি LABEL_3
#
# ০২৩১ ০২ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1767.jpeg
#
# OCR Output:
# ৬ দে (( ৬চগছচ ^@4/{ [> চট্ট মেঢ্রো চ ১১-২৬৯৩ সৈকত (
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.99968976, 'word': '৬ দে ( ( ৬চগছচ ^ @ 4 / { [ >', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.92842704, 'word': 'চটট', 'start': 23, 'end': 27}, {'entity_group': 'LABEL_2', 'score': 0.9425367, 'word': 'মেঢরো', 'start': 28, 'end': 34}, {'entity_group': 'LABEL_0', 'score': 0.99769, 'word': 'চ ১১ - ২৬৯৩ সৈকত (', 'start': 35, 'end': 51}]
#
# Entity word:	Entity label:
# ৬ দে ( ( ৬চগছচ ^ @ 4 / { [ > LABEL_0
#
# চটট LABEL_1
#
# মেঢরো LABEL_2
#
# চ ১১ - ২৬৯৩ সৈকত ( LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1764.jpeg
#
# OCR Output:
# মযমনসিংহ- ১১-৮৬২৪
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.5788711, 'word': 'ম', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_3', 'score': 0.5424491, 'word': '##যমনসি', 'start': 1, 'end': 6}, {'entity_group': 'LABEL_5', 'score': 0.52732134, 'word': '##ংহ', 'start': 6, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.99702686, 'word': '- ১১ - ৮৬২৪', 'start': 8, 'end': 17}]
#
# Entity word:	Entity label:
# ম LABEL_5
#
# ##যমনসি LABEL_3
#
# ##ংহ LABEL_5
#
# - ১১ - ৮৬২৪ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1771.jpeg
#
# OCR Output:
# ঢাকামেট্রো হ৫০ ০২০৩ 2 0401<93[40613 "76{[
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9992903, 'word': 'ঢাকামেটরো', 'start': 0, 'end': 10}, {'entity_group': 'LABEL_4', 'score': 0.9986897, 'word': 'হ৫০ ০২০৩', 'start': 11, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.99962586, 'word': '2 0401 < 93 [ 40613 " 76 { [', 'start': 20, 'end': 41}]
#
# Entity word:	Entity label:
# ঢাকামেটরো LABEL_3
#
# হ৫০ ০২০৩ LABEL_4
#
# 2 0401 < 93 [ 40613 " 76 { [ LABEL_0
#
# --------------------------------------------------
# Image: Vehicle1766.jpeg
#
# OCR Output:
# ১১-০৯৯৬ 1 খাগড়াছড়ি-
#
# Named Entities:
# ...
#
# Entity word:	Entity label:
# 1 LABEL_0
#
# গাহল LABEL_1
#
# টাং LABEL_2
#
# ৭99৩ ১৪ - LABEL_0
#
# --------------------------------------------------
# Image: 117.jpeg
#
# OCR Output:
# টং!থইে ১১-১১৯ ক আন সেে
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9400101, 'word': 'টং', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_0', 'score': 0.94776356, 'word': '! থইে ১১ - ১১৯ ক', 'start': 2, 'end': 15}, {'entity_group': 'LABEL_1', 'score': 0.94209355, 'word': 'আ', 'start': 16, 'end': 17}, {'entity_group': 'LABEL_2', 'score': 0.90432316, 'word': '##ন সেে', 'start': 17, 'end': 22}]
#
# Entity word:	Entity label:
# টং LABEL_1
#
# ! থইে ১১ - ১১৯ ক LABEL_0
#
# আ LABEL_1
#
# ##ন সেে LABEL_2
#
# --------------------------------------------------
# Image: 118.jpeg
#
# OCR Output:
# টাংগাহল থ ১১-১৪০১
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.99699765, 'word': 'টাংগাহল', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.9697802, 'word': 'থ ১১ - ১৪০১', 'start': 8, 'end': 17}]
#
# Entity word:	Entity label:
# টাংগাহল LABEL_1
#
# থ ১১ - ১৪০১ LABEL_0
#
# --------------------------------------------------
# Image: 119.jpeg
#
# OCR Output:
# ঢাঙগাইল থ ১১০৭৩৪
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9731042, 'word': 'ঢাঙগাইল', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_4', 'score': 0.91396147, 'word': 'থ ১১০৭৩৪', 'start': 8, 'end': 16}]
#
# Entity word:	Entity label:
# ঢাঙগাইল LABEL_3
#
# থ ১১০৭৩৪ LABEL_4
#
# --------------------------------------------------
# Image: 12.jpeg
#
# OCR Output:
# ময়মনসিংহ- |5 ১৫-৪৫৫৫
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.9764519, 'word': 'মযমনসিংহ', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.9996361, 'word': '- | 5 ১৫ - ৪৫৫৫', 'start': 9, 'end': 21}]
#
# Entity word:	Entity label:
# মযমনসিংহ LABEL_5
#
# - | 5 ১৫ - ৪৫৫৫ LABEL_0
#
# --------------------------------------------------
# Image: 121.jpeg
#
# OCR Output:
# থ টগংগাছল ১১-৩০৭5
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.99823594, 'word': 'থ', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_2', 'score': 0.99875075, 'word': 'টগংগাছল', 'start': 2, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.99916154, 'word': '১১ - ৩০৭5', 'start': 10, 'end': 17}]
#
# Entity word:	Entity label:
# থ LABEL_1
#
# টগংগাছল LABEL_2
#
# ১১ - ৩০৭5 LABEL_0
#
# --------------------------------------------------
# Image: 120.jpeg
#
# OCR Output:
# টাংগাইল: ১১-১০৫৮
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9979281, 'word': 'টাংগাইল', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.9956139, 'word': ': ১১ - ১০৫৮', 'start': 7, 'end': 16}]
#
# Entity word:	Entity label:
# টাংগাইল LABEL_3
#
# : ১১ - ১০৫৮ LABEL_0
#
# --------------------------------------------------
# Image: 122.jpeg
#
# OCR Output:
# টা?গাইল থ $3 ৩[৩ @
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.8566654, 'word': 'টা? গ', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_3', 'score': 0.6189735, 'word': '##াইল', 'start': 4, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.95407, 'word': 'থ $ 3 ৩ [ ৩ @', 'start': 8, 'end': 18}]
#
# Entity word:	Entity label:
# টা? গ LABEL_0
#
# ##াইল LABEL_3
#
# থ $ 3 ৩ [ ৩ @ LABEL_0
#
# --------------------------------------------------
# Image: 123.jpeg
#
# OCR Output:
# ট7 ' ১১-২৯৬৭ গাতল
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.91934407, 'word': "ট7 ' ১১ - ২৯৬৭", 'start': 0, 'end': 12}, {'entity_group': 'LABEL_6', 'score': 0.99692196, 'word': 'গাতল', 'start': 13, 'end': 17}]
#
# Entity word:	Entity label:
# ট7 ' ১১ - ২৯৬৭ LABEL_0
#
# গাতল LABEL_6
#
# --------------------------------------------------
# Image: 124.jpeg
#
# OCR Output:
# দিনাজসন 2368 ল-১১
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99454474, 'word': 'দিনাজসন', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.9779562, 'word': '2368', 'start': 8, 'end': 12}, {'entity_group': 'LABEL_4', 'score': 0.5587251, 'word': 'ল', 'start': 13, 'end': 14}, {'entity_group': 'LABEL_0', 'score': 0.7443625, 'word': '-', 'start': 14, 'end': 15}, {'entity_group': 'LABEL_4', 'score': 0.6787181, 'word': '১১', 'start': 15, 'end': 17}]
#
# Entity word:	Entity label:
# দিনাজসন LABEL_3
#
# 2368 LABEL_0
#
# ল LABEL_4
#
# - LABEL_0
#
# ১১ LABEL_4
#
# --------------------------------------------------
# Image: 125.jpeg
#
# OCR Output:
# মেট্রো ঢাকা ১১-৬৫০৩
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99907875, 'word': 'মেটরো', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.99783796, 'word': 'ঢাকা ১১ - ৬৫০৩', 'start': 7, 'end': 19}]
#
# Entity word:	Entity label:
# মেটরো LABEL_3
#
# ঢাকা ১১ - ৬৫০৩ LABEL_4
#
# --------------------------------------------------
# Image: 126.jpeg
#
# OCR Output:
# ঢাক}  মেট্রো ৩২-৩০৯>|
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.7236078, 'word': 'ঢাক }', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_3', 'score': 0.5899328, 'word': 'মেটরো', 'start': 6, 'end': 12}, {'entity_group': 'LABEL_0', 'score': 0.9985402, 'word': '৩২ - ৩০৯ > |', 'start': 13, 'end': 21}]
#
# Entity word:	Entity label:
# ঢাক } LABEL_0
#
# মেটরো LABEL_3
#
# ৩২ - ৩০৯ > | LABEL_0
#
# --------------------------------------------------
# Image: 128.jpeg
#
# OCR Output:
# টাং 'গাইল: ১২-৪৬৬৬
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9899498, 'word': "টাং ' গাইল", 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.9974809, 'word': ': ১২ - ৪৬৬৬', 'start': 9, 'end': 18}]
#
# Entity word:	Entity label:
# টাং ' গাইল LABEL_3
#
# : ১২ - ৪৬৬৬ LABEL_0
#
# --------------------------------------------------
# Image: 129.jpeg
#
# OCR Output:
# টা ?গাইল ১২ ৩ত৫
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.48484656, 'word': 'টা?', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_3', 'score': 0.99398994, 'word': 'গাইল', 'start': 4, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.9396864, 'word': '১২ ৩ত৫', 'start': 9, 'end': 15}]
#
# Entity word:	Entity label:
# টা? LABEL_0
#
# গাইল LABEL_3
#
# ১২ ৩ত৫ LABEL_0
#
# --------------------------------------------------
# Image: 131.jpeg
#
# OCR Output:
# টাংগাইল- ১১-৭8৩০
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99644023, 'word': 'টাংগাইল', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.87196106, 'word': '- ১১ - ৭8৩০', 'start': 7, 'end': 16}]
#
# Entity word:	Entity label:
# টাংগাইল LABEL_3
#
# - ১১ - ৭8৩০ LABEL_0
#
# --------------------------------------------------
# Image: 130.jpeg
#
# OCR Output:
# ১৪-৭৮0য ঢাও567:
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.7595107, 'word': '১৪ - ৭৮0য ঢাও567 :', 'start': 0, 'end': 15}]
#
# Entity word:	Entity label:
# ১৪ - ৭৮0য ঢাও567 : LABEL_0
#
# --------------------------------------------------
# Image: 13.jpeg
#
# OCR Output:
# ময়মনসিংহ- হ ১৪-৪২২৪
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.5693526, 'word': 'ময', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_3', 'score': 0.48514384, 'word': '##মনসি', 'start': 3, 'end': 7}, {'entity_group': 'LABEL_5', 'score': 0.5658008, 'word': '##ংহ', 'start': 7, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.99897766, 'word': '- হ ১৪ - ৪২২৪', 'start': 9, 'end': 20}]
#
# Entity word:	Entity label:
# ময LABEL_5
#
# ##মনসি LABEL_3
#
# ##ংহ LABEL_5
#
# - হ ১৪ - ৪২২৪ LABEL_0
#
# --------------------------------------------------
# Image: 132.jpeg
#
# OCR Output:
# টাংগাইল ৮988
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9987502, 'word': 'টাংগাইল', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_4', 'score': 0.9848159, 'word': '৮988', 'start': 8, 'end': 12}]
#
# Entity word:	Entity label:
# টাংগাইল LABEL_3
#
# ৮988 LABEL_4
#
# --------------------------------------------------
# Image: 134.jpeg
#
# OCR Output:
# টা গাহল ১১-৮৫৫১
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9947372, 'word': 'টা', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_2', 'score': 0.99610263, 'word': 'গাহল', 'start': 3, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.99088174, 'word': '১১ - ৮৫৫১', 'start': 8, 'end': 15}]
#
# Entity word:	Entity label:
# টা LABEL_1
#
# গাহল LABEL_2
#
# ১১ - ৮৫৫১ LABEL_0
#
# --------------------------------------------------
# Image: 133.jpeg
#
# OCR Output:
# ১২-৮৫বরড ঢা গাইল:
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9452551, 'word': '১২ - ৮৫বর', 'start': 0, 'end': 7}, {'entity_group': 'LABEL_3', 'score': 0.52136475, 'word': '##ড', 'start': 7, 'end': 8}, {'entity_group': 'LABEL_4', 'score': 0.81139624, 'word': 'ঢা গাইল', 'start': 9, 'end': 16}, {'entity_group': 'LABEL_0', 'score': 0.99443746, 'word': ':', 'start': 16, 'end': 17}]
#
# Entity word:	Entity label:
# ১২ - ৮৫বর LABEL_0
#
# ##ড LABEL_3
#
# ঢা গাইল LABEL_4
#
# : LABEL_0
#
# --------------------------------------------------
# Image: 136.jpeg
#
# OCR Output:
# নারামনণগন- @ ১৯-০@৬$
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.98667103, 'word': 'নারামনণগন', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.9996901, 'word': '- @ ১৯ - ০ @ ৬ $', 'start': 9, 'end': 20}]
#
# Entity word:	Entity label:
# নারামনণগন LABEL_1
#
# - @ ১৯ - ০ @ ৬ $ LABEL_0
#
# --------------------------------------------------
# Image: 138.jpeg
#
# OCR Output:
# ম নাটোর ১১-৬৩০২
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.998336, 'word': 'ম', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_2', 'score': 0.99910504, 'word': 'নাটোর', 'start': 2, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.997698, 'word': '১১ - ৬৩০২', 'start': 8, 'end': 15}]
#
# Entity word:	Entity label:
# ম LABEL_1
#
# নাটোর LABEL_2
#
# ১১ - ৬৩০২ LABEL_0
#
# --------------------------------------------------
# Image: 137.jpeg
#
# OCR Output:
# ১১ নাঢোর- ২৮৮
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.96299887, 'word': '১১', 'start': 0, 'end': 2}, {'entity_group': 'LABEL_3', 'score': 0.5786293, 'word': 'নাঢোর', 'start': 3, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.7602305, 'word': '- ২৮৮', 'start': 8, 'end': 13}]
#
# Entity word:	Entity label:
# ১১ LABEL_0
#
# নাঢোর LABEL_3
#
# - ২৮৮ LABEL_0
#
# --------------------------------------------------
# Image: 139.jpeg
#
# OCR Output:
# নওগা ]0<0৬৬>
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9219387, 'word': 'নওগা ] 0 < 0৬৬ >', 'start': 0, 'end': 12}]
#
# Entity word:	Entity label:
# নওগা ] 0 < 0৬৬ > LABEL_0
#
# --------------------------------------------------
# Image: 14.jpeg
#
# OCR Output:
# মযামনসিংহ ১১-৮৬২৪
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.5959395, 'word': 'মযামনসিংহ', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_0', 'score': 0.932148, 'word': '১১ - ৮৬২৪', 'start': 10, 'end': 17}]
#
# Entity word:	Entity label:
# মযামনসিংহ LABEL_5
#
# ১১ - ৮৬২৪ LABEL_0
#
# --------------------------------------------------
# Image: 140.jpeg
#
# OCR Output:
# নাটোর হ ১২-২৬২৭
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9983525, 'word': 'নাটোর', 'start': 0, 'end': 5}, {'entity_group': 'LABEL_2', 'score': 0.99447507, 'word': 'হ', 'start': 6, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.9921133, 'word': '১২ - ২৬২৭', 'start': 8, 'end': 15}]
#
# Entity word:	Entity label:
# নাটোর LABEL_1
#
# হ LABEL_2
#
# ১২ - ২৬২৭ LABEL_0
#
# --------------------------------------------------
# Image: 141.jpeg
#
# OCR Output:
# নাঢেো ১১-০৮৯৪
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.988635, 'word': 'নাঢেো', 'start': 0, 'end': 5}, {'entity_group': 'LABEL_0', 'score': 0.97604394, 'word': '১১ - ০৮৯৪', 'start': 6, 'end': 13}]
#
# Entity word:	Entity label:
# নাঢেো LABEL_3
#
# ১১ - ০৮৯৪ LABEL_0
#
# --------------------------------------------------
# Image: 142.jpeg
#
# OCR Output:
# নটোরুত ১৩৭৭১৬
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9980815, 'word': 'নটোরত', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.9981826, 'word': '১৩৭৭১৬', 'start': 7, 'end': 13}]
#
# Entity word:	Entity label:
# নটোরত LABEL_3
#
# ১৩৭৭১৬ LABEL_4
#
# --------------------------------------------------
# Image: 143.jpeg
#
# OCR Output:
# ঢাকা মেট্রৌ-ফ ১১-১০১০
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9992804, 'word': 'ঢাকা', 'start': 0, 'end': 4}, {'entity_group': 'LABEL_4', 'score': 0.96786386, 'word': 'মেটরৌ - ফ ১১ - ১০১০', 'start': 5, 'end': 21}]
#
# Entity word:	Entity label:
# ঢাকা LABEL_3
#
# মেটরৌ - ফ ১১ - ১০১০ LABEL_4
#
# --------------------------------------------------
# Image: 144.jpeg
#
# OCR Output:
# হ বরিশাল মেট্রো- ১২-৭৬৪৩
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9972849, 'word': 'হ', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_4', 'score': 0.98832285, 'word': 'বরিশাল মেটরো - ১২', 'start': 2, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.7092198, 'word': '-', 'start': 19, 'end': 20}, {'entity_group': 'LABEL_4', 'score': 0.8427632, 'word': '৭৬৪৩', 'start': 20, 'end': 24}]
#
# Entity word:	Entity label:
# হ LABEL_3
#
# বরিশাল মেটরো - ১২ LABEL_4
#
# - LABEL_0
#
# ৭৬৪৩ LABEL_4
#
# --------------------------------------------------
# Image: 145.jpeg
#
# OCR Output:
# পটুয়াখালী 8038
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.99563754, 'word': 'পটযাখালী', 'start': 0, 'end': 9}, {'entity_group': 'LABEL_6', 'score': 0.9716803, 'word': '8038', 'start': 10, 'end': 14}]
#
# Entity word:	Entity label:
# পটযাখালী LABEL_5
#
# 8038 LABEL_6
#
# --------------------------------------------------
# Image: 146.jpeg
#
# OCR Output:
# @ মেট্রো ঢাকী ২২-৫৮৭৯
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9993844, 'word': '@', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_3', 'score': 0.9961227, 'word': 'মেটরো', 'start': 2, 'end': 8}, {'entity_group': 'LABEL_4', 'score': 0.9925727, 'word': 'ঢাকী', 'start': 9, 'end': 13}, {'entity_group': 'LABEL_0', 'score': 0.9600187, 'word': '২২ - ৫৮৭৯', 'start': 14, 'end': 21}]
#
# Entity word:	Entity label:
# @ LABEL_0
#
# মেটরো LABEL_3
#
# ঢাকী LABEL_4
#
# ২২ - ৫৮৭৯ LABEL_0
#
# --------------------------------------------------
# Image: 147.jpeg
#
# OCR Output:
# $ ৩৬
#
# Named Entities:
# [{'entity_group': 'LABEL_0', 'score': 0.9247999, 'word': '$ ৩৬', 'start': 0, 'end': 4}]
#
# Entity word:	Entity label:
# $ ৩৬ LABEL_0
#
# --------------------------------------------------
# Image: 148.jpeg
#
# OCR Output:
# নাটোর ৯০৯
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99900603, 'word': 'নাটোর', 'start': 0, 'end': 5}, {'entity_group': 'LABEL_4', 'score': 0.99864316, 'word': '৯০৯', 'start': 6, 'end': 9}]
#
# Entity word:	Entity label:
# নাটোর LABEL_3
#
# ৯০৯ LABEL_4
#
# --------------------------------------------------
# Image: 15.jpeg
#
# OCR Output:
# খাগড়াছড়ি: ১১-৬৯৪৩
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.99499816, 'word': 'খাগডাছডি', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.9973145, 'word': ': ১১ - ৬৯৪৩', 'start': 8, 'end': 17}]
#
# Entity word:	Entity label:
# খাগডাছডি LABEL_3
#
# : ১১ - ৬৯৪৩ LABEL_0
#
# --------------------------------------------------
# Image: 150.jpeg
#
# OCR Output:
# মেট্রো হ ঢাকা ৫৩-৩৬ '
#
# Named Entities:
# [{'entity_group': 'LABEL_3', 'score': 0.9987258, 'word': 'মেটরো', 'start': 0, 'end': 6}, {'entity_group': 'LABEL_4', 'score': 0.9970862, 'word': 'হ ঢাকা', 'start': 7, 'end': 13}, {'entity_group': 'LABEL_0', 'score': 0.8181223, 'word': "৫৩ - ৩৬ '", 'start': 14, 'end': 21}]
#
# Entity word:	Entity label:
# মেটরো LABEL_3
#
# হ ঢাকা LABEL_4
#
# ৫৩ - ৩৬ ' LABEL_0
#
# --------------------------------------------------
# Image: 149.jpeg
#
# OCR Output:
# বগুড়া ১ -০৮১
#
# Named Entities:
# [{'entity_group': 'LABEL_5', 'score': 0.99305266, 'word': 'বগডা', 'start': 0, 'end': 5}, {'entity_group': 'LABEL_0', 'score': 0.9925537, 'word': '১ - ০৮১', 'start': 6, 'end': 12}]
#
# Entity word:	Entity label:
# বগডা LABEL_5
#
# ১ - ০৮১ LABEL_0
#
# --------------------------------------------------
# Image: 151.jpeg
#
# OCR Output:
# ল বগুড়া- ১৩-২৩৬৯
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.9990175, 'word': 'ল', 'start': 0, 'end': 1}, {'entity_group': 'LABEL_2', 'score': 0.99912643, 'word': 'বগডা', 'start': 2, 'end': 7}, {'entity_group': 'LABEL_0', 'score': 0.99933106, 'word': '- ১৩ - ২৩৬৯', 'start': 7, 'end': 16}]
#
# Entity word:	Entity label:
# ল LABEL_1
#
# বগডা LABEL_2
#
# - ১৩ - ২৩৬৯ LABEL_0
#
# --------------------------------------------------
# Image: 152.jpeg
#
# OCR Output:
# নটটোর; হ ১২-১৯৮৯
#
# Named Entities:
# [{'entity_group': 'LABEL_1', 'score': 0.98245823, 'word': 'নটটোর', 'start': 0, 'end': 5}, {'entity_group': 'LABEL_0', 'score': 0.9990152, 'word': '; হ ১২ - ১৯৮৯', 'start': 5, 'end': 16}]
#
# Entity word:	Entity label:
# নটটোর LABEL_1
#
# ; হ ১২ - ১৯৮৯ LABEL_0
#
# --------------------------------------------------
